# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import PIL

# %%
print('total Airplane images :', len(os.listdir('../../../Dataset/train/Airplane')))
print('total Bottle images :', len(os.listdir('../../../Dataset/train/Bottle')))
print('total Camera images :', len(os.listdir('../../../Dataset/train/Camera')))
print('total Mouse images :', len(os.listdir('../../../Dataset/train/Computer Mouse')))
print('total Cookie images :', len(os.listdir('../../../Dataset/train/Cookie')))
print('total Laptop images :', len(os.listdir('../../../Dataset/train/Laptop')))
print('total Phone images :', len(os.listdir('../../../Dataset/train/Mobile phone')))
print('total Motorcycle images :', len(os.listdir('../../../Dataset/train/Motorcycle')))
print('total Pool images :', len(os.listdir('../../../Dataset/train/Swimming pool')))
print('total Zebra images :', len(os.listdir('../../../Dataset/train/Zebra')))
# Out:
# total Airplane images : 1001
# total Bottle images : 1260
# total Camera images : 1201
# total Mouse images : 468
# total Cookie images : 682
# total Laptop images : 1215
# total Phone images : 1188
# total Motorcycle images : 1301
# total Pool images : 1301
# total Zebra images : 489

# %%
file_dir = '../../../Dataset/train/'

# %%
import imageio
directory=os.listdir('../../../Dataset/train')
for each in directory:
    plt.figure()
    currentFolder = '../../../Dataset/train/' + each
    for i, file in enumerate(os.listdir(currentFolder)[5:9]):
        fullpath = currentFolder+ "/" + file
        print(fullpath)
        img=imageio.imread(fullpath)
        plt.title(each)
        plt.subplot(2, 2, i+1)
        plt.imshow(img)
# Out:
# ../../../Dataset/train/Airplane/00460ef1717ec160.jpg
# ../../../Dataset/train/Airplane/0047df63349eaa1d.jpg
# ../../../Dataset/train/Airplane/00529857b7d0daa8.jpg
# ../../../Dataset/train/Airplane/00558ef5c7387376.jpg
# ../../../Dataset/train/Bottle/001f677238125955.jpg
# ../../../Dataset/train/Bottle/0023199523656671.jpg
# ../../../Dataset/train/Bottle/0025cecdac634ec0.jpg
# ../../../Dataset/train/Bottle/002e95630bcc27ef.jpg
# ../../../Dataset/train/Camera/0018973d9b1d6579.jpg
# ../../../Dataset/train/Camera/001e2f865006d646.jpg
# ../../../Dataset/train/Camera/00251745f963f8bc.jpg
# ../../../Dataset/train/Camera/003410a218b0cd59.jpg
# ../../../Dataset/train/Computer mouse/005d015cd459f7d7.jpg
# ../../../Dataset/train/Computer mouse/00710a1936574ff7.jpg
# ../../../Dataset/train/Computer mouse/0078bf6d54a54e9b.jpg
# ../../../Dataset/train/Computer mouse/0080e6892a3992d8.jpg
# ../../../Dataset/train/Cookie/0030d3b9430331d0.jpg
# ../../../Dataset/train/Cookie/003ccc97fd6e5ae1.jpg
# ../../../Dataset/train/Cookie/003ecf27fe8fef34.jpg
# ../../../Dataset/train/Cookie/006b0ca81c7dcb10.jpg
# ../../../Dataset/train/Laptop/00112c426578e854.jpg
# ../../../Dataset/train/Laptop/0015c6105c9e7a3a.jpg
# ../../../Dataset/train/Laptop/0016730ee38621fd.jpg
# ../../../Dataset/train/Laptop/001b963bc073ef19.jpg
# ../../../Dataset/train/Mobile phone/001ea39577de276e.jpg
# ../../../Dataset/train/Mobile phone/001f581f2f2db648.jpg
# ../../../Dataset/train/Mobile phone/00265dc299fe941e.jpg
# ../../../Dataset/train/Mobile phone/002b6c5e434980df.jpg
# ../../../Dataset/train/Motorcycle/00314693104a04cf.jpg
# ../../../Dataset/train/Motorcycle/003cbfe39ab31fe3.jpg
# ../../../Dataset/train/Motorcycle/004104019f543c94.jpg
# ../../../Dataset/train/Motorcycle/0049ed70c1b2d480.jpg
# ../../../Dataset/train/Swimming pool/001120790dc85884.jpg
# ../../../Dataset/train/Swimming pool/0014778c71ad81ae.jpg
# ../../../Dataset/train/Swimming pool/0014f79a71bd5e17.jpg
# ../../../Dataset/train/Swimming pool/001ca039e68c81ac.jpg
# ../../../Dataset/train/Zebra/01781e9f613ee2a3.jpg
# ../../../Dataset/train/Zebra/01baed52b49e2346.jpg
# ../../../Dataset/train/Zebra/01de6ec879e39395.jpg
# ../../../Dataset/train/Zebra/01f098c1af03b8ea.jpg

# %%
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.applications.resnet_v2 import ResNet152V2, preprocess_input
from tensorflow.python.keras.layers.normalization import BatchNormalization
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Dropout, Activation, Flatten, UpSampling2D, GlobalAveragePooling2D, GlobalMaxPooling2D
from tensorflow.python.keras.layers import Conv2D, MaxPooling2D
from tensorflow.python.keras.applications.xception import Xception
train_dir = os.path.join(file_dir)
train_datagen = ImageDataGenerator(rescale=1./255,
    rotation_range=90,
    zoom_range=0.2,
    shear_range=0.2,
    fill_mode = 'nearest',
    validation_split=0.2) # set validation split
# Out:
# Using TensorFlow backend.

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(220, 220),
    batch_size=16,
    class_mode='categorical',
    subset='training') # set as training data
validation_generator = train_datagen.flow_from_directory(
    train_dir, # same directory as training data
    target_size=(220, 220),
    batch_size=32,
    class_mode='categorical',
    subset='validation')
# Out:
# Found 8080 images belonging to 10 classes.
# Found 2016 images belonging to 10 classes.

# %%
filepath = 'best_model_openimage.h5'

checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True)
stop =  EarlyStopping(monitor='accuracy', min_delta=0.01, patience =4,
                      verbose=0, mode='auto', baseline=None, 
                      restore_best_weights=False)
callbacks = [checkpoint,stop]

resnet_model = ResNet152V2(weights='imagenet', include_top=False, input_shape=(220, 220, 3), classes = 10)

for layer in resnet_model.layers:
    if isinstance(layer, BatchNormalization):
        layer.trainable = True
    else:
        layer.trainable = False
epochs=50
model = Sequential()
# model.add(UpSampling2D())
# model.add(UpSampling2D())
# model.add(UpSampling2D())
model.add(resnet_model)
model.add(GlobalMaxPooling2D())
model.add(Dense(256, activation='relu'))
model.add(Dropout(.25))
model.add(BatchNormalization())
model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer=tf.optimizers.Adam(),
              loss='categorical_crossentropy',
              metrics = ['accuracy'])

# %%
history = model.fit(train_generator,
                              validation_data=validation_generator,
                              epochs=epochs,
                              verbose=1, callbacks=callbacks)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 505 steps, validate for 63 steps
# Epoch 1/50
# 504/505 [============================>.] - ETA: 0s - loss: 1.0016 - accuracy: 0.6729
# Epoch 00001: val_accuracy improved from -inf to 0.81796, saving model to best_model_openimage.h5
# 505/505 [==============================] - 151s 298ms/step - loss: 1.0008 - accuracy: 0.6733 - val_loss: 0.5809 - val_accuracy: 0.8180
# Epoch 2/50
# 504/505 [============================>.] - ETA: 0s - loss: 0.7528 - accuracy: 0.7543
# Epoch 00002: val_accuracy improved from 0.81796 to 0.84524, saving model to best_model_openimage.h5
# 505/505 [==============================] - 140s 278ms/step - loss: 0.7523 - accuracy: 0.7545 - val_loss: 0.5483 - val_accuracy: 0.8452
# Epoch 3/50
# 504/505 [============================>.] - ETA: 0s - loss: 0.6558 - accuracy: 0.7861
# Epoch 00003: val_accuracy improved from 0.84524 to 0.85417, saving model to best_model_openimage.h5
# 505/505 [==============================] - 140s 278ms/step - loss: 0.6558 - accuracy: 0.7861 - val_loss: 0.4538 - val_accuracy: 0.8542
# Epoch 4/50
# 504/505 [============================>.] - ETA: 0s - loss: 0.6049 - accuracy: 0.8002
# Epoch 00004: val_accuracy did not improve from 0.85417
# 505/505 [==============================] - 139s 275ms/step - loss: 0.6050 - accuracy: 0.8002 - val_loss: 0.4427 - val_accuracy: 0.8537
# Epoch 5/50
# 504/505 [============================>.] - ETA: 0s - loss: 0.5756 - accuracy: 0.8114
# Epoch 00005: val_accuracy improved from 0.85417 to 0.85913, saving model to best_model_openimage.h5
# 505/505 [==============================] - 140s 277ms/step - loss: 0.5753 - accuracy: 0.8115 - val_loss: 0.4119 - val_accuracy: 0.8591
# Epoch 6/50
# 504/505 [============================>.] - ETA: 0s - loss: 0.5425 - accuracy: 0.8239
# Epoch 00006: val_accuracy improved from 0.85913 to 0.87054, saving model to best_model_openimage.h5
# 505/505 [==============================] - 140s 278ms/step - loss: 0.5425 - accuracy: 0.8240 - val_loss: 0.4065 - val_accuracy: 0.8705
# Epoch 7/50
# 504/505 [============================>.] - ETA: 0s - loss: 0.5140 - accuracy: 0.8300
# Epoch 00007: val_accuracy improved from 0.87054 to 0.87351, saving model to best_model_openimage.h5
# 505/505 [==============================] - 140s 277ms/step - loss: 0.5136 - accuracy: 0.8302 - val_loss: 0.3813 - val_accuracy: 0.8735
# Epoch 8/50
# 504/505 [============================>.] - ETA: 0s - loss: 0.4952 - accuracy: 0.8326
# Epoch 00008: val_accuracy improved from 0.87351 to 0.87798, saving model to best_model_openimage.h5
# 505/505 [==============================] - 141s 280ms/step - loss: 0.4956 - accuracy: 0.8323 - val_loss: 0.3758 - val_accuracy: 0.8780
# Epoch 9/50
# 504/505 [============================>.] - ETA: 0s - loss: 0.4762 - accuracy: 0.8423
# Epoch 00009: val_accuracy did not improve from 0.87798
# 505/505 [==============================] - 141s 279ms/step - loss: 0.4759 - accuracy: 0.8425 - val_loss: 0.3798 - val_accuracy: 0.8750
# Epoch 10/50
# 504/505 [============================>.] - ETA: 0s - loss: 0.4509 - accuracy: 0.8485
# Epoch 00010: val_accuracy did not improve from 0.87798
# 505/505 [==============================] - 141s 280ms/step - loss: 0.4510 - accuracy: 0.8484 - val_loss: 0.3774 - val_accuracy: 0.8760
# Epoch 11/50
# 504/505 [============================>.] - ETA: 0s - loss: 0.4412 - accuracy: 0.8545
# Epoch 00011: val_accuracy improved from 0.87798 to 0.89335, saving model to best_model_openimage.h5
# 505/505 [==============================] - 141s 279ms/step - loss: 0.4414 - accuracy: 0.8545 - val_loss: 0.3491 - val_accuracy: 0.8934
# Epoch 12/50
# 504/505 [============================>.] - ETA: 0s - loss: 0.4150 - accuracy: 0.8626
# Epoch 00012: val_accuracy did not improve from 0.89335
# 505/505 [==============================] - 140s 277ms/step - loss: 0.4152 - accuracy: 0.8625 - val_loss: 0.3732 - val_accuracy: 0.8839
# Epoch 13/50
# 504/505 [============================>.] - ETA: 0s - loss: 0.3961 - accuracy: 0.8688
# Epoch 00013: val_accuracy did not improve from 0.89335
# 505/505 [==============================] - 139s 276ms/step - loss: 0.3963 - accuracy: 0.8684 - val_loss: 0.3780 - val_accuracy: 0.8795
# Epoch 14/50
# 504/505 [============================>.] - ETA: 0s - loss: 0.3852 - accuracy: 0.8712
# Epoch 00014: val_accuracy did not improve from 0.89335
# 505/505 [==============================] - 139s 276ms/step - loss: 0.3853 - accuracy: 0.8709 - val_loss: 0.3726 - val_accuracy: 0.8795
# Epoch 15/50
# 504/505 [============================>.] - ETA: 0s - loss: 0.3681 - accuracy: 0.8738
# Epoch 00015: val_accuracy did not improve from 0.89335
# 505/505 [==============================] - 139s 276ms/step - loss: 0.3677 - accuracy: 0.8739 - val_loss: 0.4115 - val_accuracy: 0.8805
# Epoch 16/50
# 504/505 [============================>.] - ETA: 0s - loss: 0.3622 - accuracy: 0.8785
# Epoch 00016: val_accuracy did not improve from 0.89335
# 505/505 [==============================] - 139s 276ms/step - loss: 0.3629 - accuracy: 0.8782 - val_loss: 0.3670 - val_accuracy: 0.8814
# Epoch 17/50
# 504/505 [============================>.] - ETA: 0s - loss: 0.3619 - accuracy: 0.8806
# Epoch 00017: val_accuracy did not improve from 0.89335
# 505/505 [==============================] - 139s 276ms/step - loss: 0.3621 - accuracy: 0.8803 - val_loss: 0.3716 - val_accuracy: 0.8810
# Epoch 18/50
# 504/505 [============================>.] - ETA: 0s - loss: 0.3497 - accuracy: 0.8800
# Epoch 00018: val_accuracy did not improve from 0.89335
# 505/505 [==============================] - 139s 276ms/step - loss: 0.3498 - accuracy: 0.8800 - val_loss: 0.3791 - val_accuracy: 0.8849
# Epoch 19/50
# 504/505 [============================>.] - ETA: 0s - loss: 0.3417 - accuracy: 0.8801
# Epoch 00019: val_accuracy did not improve from 0.89335
# 505/505 [==============================] - 139s 276ms/step - loss: 0.3413 - accuracy: 0.8802 - val_loss: 0.3561 - val_accuracy: 0.8864
# Epoch 20/50
# 504/505 [============================>.] - ETA: 0s - loss: 0.3398 - accuracy: 0.8864
# Epoch 00020: val_accuracy did not improve from 0.89335
# 505/505 [==============================] - 139s 275ms/step - loss: 0.3400 - accuracy: 0.8864 - val_loss: 0.3484 - val_accuracy: 0.8864
# Epoch 21/50
# 504/505 [============================>.] - ETA: 0s - loss: 0.3170 - accuracy: 0.8893
# Epoch 00021: val_accuracy did not improve from 0.89335
# 505/505 [==============================] - 139s 275ms/step - loss: 0.3167 - accuracy: 0.8894 - val_loss: 0.3463 - val_accuracy: 0.8879

# %%
numOfEpoch = 21

plt.figure(figsize=(14, 4))

plt.subplot(1,2,1)
plt.plot(np.arange(0, numOfEpoch), history.history['loss'], 'bo', label='Training loss')
plt.plot(np.arange(0, numOfEpoch), history.history['val_loss'], 'b', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1,2,2)
plt.plot(np.arange(0, numOfEpoch), history.history['accuracy'], 'bo', 
         label='Accuracy', c='orange')
plt.plot(np.arange(0, numOfEpoch), history.history['val_accuracy'], 'b', 
         label='Validation accuracy', c='orange')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# %%
with tf.io.gfile.GFile('model-cifar.tflite', 'wb') as f:
    f.write(tflite_model)
